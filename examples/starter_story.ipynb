# %%
from youtube_transcript_collector import (
    get_channel_id,
    load_config_from_env,
    get_all_video_ids,
    download_channel_transcripts,
)

# Load API key from .env file
api_key = load_config_from_env()

# Getting the channel id
starter_story_channel_id = get_channel_id(
    "https://www.youtube.com/@starterstory", api_key
)

# getting the recent videos list
video_ids = get_all_video_ids(starter_story_channel_id, api_key, max_results=50)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from youtube_transcript_collector import (
#       2     get_channel_id,
#       3     load_config_from_env,
#       4     get_all_video_ids,
#       5     download_channel_transcripts,
#       6 )
#       8 # Load API key from .env file
#       9 api_key = load_config_from_env()
#
# ModuleNotFoundError: No module named 'youtube_transcript_collector'

# %%
download_channel_transcripts(starter_story_channel_id, api_key, max_videos=2)
